# %%
# MW

            if body_direction == 'Front' and body_status == 'MW' and head_direction == 'Front':
                label = 'F'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'MW' and head_direction == 'Back':
                label = 'F'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'MW' and head_direction == 'Left':
                label = 'F,L'
                value = [99.7, 0.3]
                return label, value

            elif body_direction == 'Front' and body_status == 'MW' and head_direction == 'Right':
                label = 'F,R'
                value = [99.7, 0.3]
                return label, value

            elif body_direction == 'Back' and body_status == 'MW' and head_direction == 'Front':
                label = 'B'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'MW' and head_direction == 'Back':
                label = 'B'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'MW' and head_direction == 'Left':
                label = 'B,L'
                value = [99.2, 0.8]
                return label, value

            elif body_direction == 'Back' and body_status == 'MW' and head_direction == 'Right':
                label = 'B,R'
                value = [99.2, 0.8]
                return label, value

            elif body_direction == 'Left' and body_status == 'MW' and head_direction == 'Front':
                label = 'L,F'
                value = [99.4, 0.6]
                return label, value

            elif body_direction == 'Left' and body_status == 'MW' and head_direction == 'Back':
                label = 'L,B'
                value = [99.4, 0.6]
                return label, value

            elif body_direction == 'Left' and body_status == 'MW' and head_direction == 'Left':
                label = 'L'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'MW' and head_direction == 'Right':
                label = 'L'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'MW' and head_direction == 'Front':
                label = 'R,F'
                value = [99.5, 0.5]
                return label, value

            elif body_direction == 'Right' and body_status == 'MW' and head_direction == 'Back':
                label = 'R,B'
                value = [99.5, 0.5]
                return label, value

            elif body_direction == 'Right' and body_status == 'MW' and head_direction == 'Left':
                label = 'R'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'MW' and head_direction == 'Right':
                label = 'R'
                value = [100]
                return label, value


  # MR

            elif body_direction == 'Front' and body_status == 'MR' and head_direction == 'Front':
                label = 'F'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'MR' and head_direction == 'Back':
                label = 'F'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'MR' and head_direction == 'Left':
                label = 'F,L'
                value = [99.7, 0.3]
                return label, value

            elif body_direction == 'Front' and body_status == 'MR' and head_direction == 'Right':
                label = 'F,R'
                value = [99.7, 0.3]
                return label, value

            elif body_direction == 'Back' and body_status == 'MR' and head_direction == 'Front':
                label = 'B'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'MR' and head_direction == 'Back':
                label = 'B'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'MR' and head_direction == 'Left':
                label = 'B,L'
                value = [99.2, 0.8]
                return label, value

            elif body_direction == 'Back' and body_status == 'MR' and head_direction == 'Right':
                label = 'B,R'
                value = [99.2, 0.8]
                return label, value

            elif body_direction == 'Left' and body_status == 'MR' and head_direction == 'Front':
                label = 'L,F'
                value = [99.4, 0.6]
                return label, value

            elif body_direction == 'Left' and body_status == 'MR' and head_direction == 'Back':
                label = 'L,B'
                value = [99.4, 0.6]
                return label, value

            elif body_direction == 'Left' and body_status == 'MR' and head_direction == 'Left':
                label = 'L'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'MR' and head_direction == 'Right':
                label = 'L'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'MR' and head_direction == 'Front':
                label = 'R,F'
                value = [99.5, 0.5]
                return label, value

            elif body_direction == 'Right' and body_status == 'MR' and head_direction == 'Back':
                label = 'R,B'
                value = [99.5, 0.5]
                return label, value

            elif body_direction == 'Right' and body_status == 'MR' and head_direction == 'Left':
                label = 'R'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'MR' and head_direction == 'Right':
                label = 'R'
                value = [100]
                return label, value



# SU

            elif body_direction == 'Front' and body_status == 'SU' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SU' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SU' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SU' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SU' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SU' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SU' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SU' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SU' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SU' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SU' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SU' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SU' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SU' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SU' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SU' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value


# SD

            elif body_direction == 'Front' and body_status == 'SD' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SD' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SD' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Front' and body_status == 'SD' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SD' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SD' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SD' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Back' and body_status == 'SD' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SD' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SD' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SD' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Left' and body_status == 'SD' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SD' and head_direction == 'Front':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SD' and head_direction == 'Back':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SD' and head_direction == 'Left':
                label = 'S'
                value = [100]
                return label, value

            elif body_direction == 'Right' and body_status == 'SD' and head_direction == 'Right':
                label = 'S'
                value = [100]
                return label, value


            else:
                return label, value
